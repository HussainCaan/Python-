# %%
import numpy as np

# %%
array1 = np.array([1, 2, 3, 4, 5])
print("Array:", array1)
print("Shape:", array1.shape)
print("Data Type:", array1.dtype)
# Out:
# Array: [1 2 3 4 5]
# Shape: (5,)
# Data Type: int64

# %%
array2 = np.array([[1, 2, 3], [4, 5, 6]])
print("2D Array:\n", array2)
print("Shape:", array2.shape)
print("Data Type:", array2.dtype)
# Out:
# 2D Array:
#  [[1 2 3]
#  [4 5 6]]
# Shape: (2, 3)
# Data Type: int64

# %%
list1 =  [[7, 8, 9], [10, 11, 12]]
array3 = np.array(list1)
print("Array from list:", array3)
print("Shape:", array3.shape)
print("Data Type:", array3.dtype)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 list1 =  [[7, 8, 9], [10, 11, 12],'float32']
# ----> 2 array3 = np.array(list1)
#       3 print("Array from list:", array3)
#       4 print("Shape:", array3.shape)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
