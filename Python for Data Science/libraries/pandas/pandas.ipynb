# %% [markdown]
# # APPLICATIONS
# ##### 1.WEB SCRAPING
# ##### 2.WEB DEVELOPMENT
# ##### 3.Data ANALYSIS
# ##### 4.FEATURE ENGINEERING AND MANY MORE

# %%
import pandas as pd

# %%
XYZ_web = {'day': [1, 2, 3, 4, 5, 6],
           'visitors': [1000, 800, 1200, 1500, 1100, 900],
           'bounce_rate': [0.2, 0.3, 0.25, 0.15, 0.3, 0.4]}

# %%
df = pd.DataFrame(XYZ_web)
df.set_index('day', inplace=True)
df
# Out:
#      visitors  bounce_rate
# day
# 1        1000         0.20
# 2         800         0.30
# 3        1200         0.25
# 4        1500         0.15
# 5        1100         0.30
# 6         900         0.40

# %%
print(df.head(2))
# Out:
#      visitors  bounce_rate
# day
# 1        1000          0.2
# 2         800          0.3

# %%
print(df.tail(2))
# Out:
#      visitors  bounce_rate
# day
# 5        1100          0.3
# 6         900          0.4
